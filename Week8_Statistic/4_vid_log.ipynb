# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/math-for-machine-learning/main/1_log/revenue.csv")

# %%
df
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
plt.bar(df["company"] , df["revenue"] )
# Out:
# <BarContainer object of 6 artists>

# %%
df.plot(x='company' , y='revenue' , kind='bar' , logy=True)
# Out:
# <Axes: xlabel='company'>
